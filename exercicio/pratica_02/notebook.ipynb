# %% [markdown]
# ![](imagens/objetivo_a.PNG)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Criar uma imagem vazia
img = np.zeros((256, 256), dtype=np.uint8)

# Gerar um degradê
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        img[i, j] = i

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# Adicionar uma moldura
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if (i >= 8 and i <= 24) or (i >= 232 and i <= 248) or (j >= 8 and j <= 24) or (j >= 232 and j <= 248):
            img[i, j] = 128

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ![](imagens/objetivo_b.PNG)

# %%
im = cv.imread("lena.png")

im_gray = im[:, :, 0] # Transformando imagem em grayscale
plt.imshow(im_gray, cmap="gray")
plt.show()

# Imagem clara
im_clara = im_gray.copy() 
linha, col = im_clara.shape
for i in range(linha):
    for j in range(col):
        produto = im_clara[i, j] + (im_clara[i, j] * 0.8)

        if (produto > 255):
            produto = 255
        elif (produto < 0):
            produto = 0

        im_clara[i, j] = produto

plt.imshow(im_clara, cmap="gray")
plt.show()

# Imagem escura
im_escura = im_gray.copy()
linha, col = im_escura.shape
for i in range(linha):
    for j in range(col):
        produto = im_escura[i, j] - (im_escura[i, j] * 0.8)

        if (produto > 255):
            produto = 255
        elif (produto < 0):
            produto = 0
        im_escura[i, j] = produto

print(im_escura)

    
plt.imshow(im_escura, cmap="gray")
plt.show()
